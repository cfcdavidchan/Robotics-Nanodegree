# %% [markdown]
# ## Rover Project Test Notebook
# This notebook contains the functions from the lesson and provides the scaffolding you need to test out your mapping methods.  The steps you need to complete in this notebook for the project are the following:
#
# * First just run each of the cells in the notebook, examine the code and the results of each.
# * Run the simulator in "Training Mode" and record some data. Note: the simulator may crash if you try to record a large (longer than a few minutes) dataset, but you don't need a ton of data, just some example images to work with.
# * Change the data directory path (2 cells below) to be the directory where you saved data
# * Test out the functions provided on your data
# * Write new functions (or modify existing ones) to report and map out detections of obstacles and rock samples (yellow rocks)
# * Populate the `process_image()` function with the appropriate steps/functions to go from a raw image to a worldmap.
# * Run the cell that calls `process_image()` using `moviepy` functions to create video output
# * Once you have mapping working, move on to modifying `perception.py` and `decision.py` to allow your rover to navigate and map in autonomous mode!
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# **Run the next cell to get code highlighting in the markdown cells.**

# %%
# %%HTML
# <style> code {background-color : orange !important;} </style>
# Out:
# <style> code {background-color : orange !important;} </style>

# %%
# %matplotlib inline
#%matplotlib qt # Choose %matplotlib qt to plot to an interactive window (note it may show up behind your browser)
# Make some of the relevant imports
import cv2 # OpenCV for perspective transform
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import scipy.misc # For saving images as needed
import glob  # For reading in a list of images from a folder

# %% [markdown]
# ## Quick Look at the Data
# There's some example data provided in the `test_dataset` folder.  This basic dataset is enough to get you up and running but if you want to hone your methods more carefully you should record some data of your own to sample various scenarios in the simulator.
#
# Next, read in and display a random image from the `test_dataset` folder

# %%
path = '../test_dataset/IMG/*'
img_list = glob.glob(path)
#print(img_list)
# Grab a random image and display it
idx = np.random.randint(0, len(img_list)-1)
image = mpimg.imread(img_list[idx])
plt.imshow(image)

# %% [markdown]
# ## Calibration Data
# Read in and display example grid and rock sample calibration images.  You'll use the grid for perspective transform and the rock image for creating a new color selection that identifies these samples of interest.

# %%
# In the simulator you can toggle on a grid on the ground for calibration
# You can also toggle on the rock samples with the 0 (zero) key.  
# Here's an example of the grid and one of the rocks
example_grid = '../calibration_images/example_grid1.jpg'
example_rock = '../calibration_images/example_rock1.jpg'
grid_img = mpimg.imread(example_grid)
rock_img = mpimg.imread(example_rock)

fig = plt.figure(figsize=(12,3))
plt.subplot(121)
plt.imshow(grid_img)
plt.subplot(122)
plt.imshow(rock_img)

# %% [markdown]
# ## Perspective Transform
#
# Define the perspective transform function from the lesson and test it on an image.

# %%
# Define a function to perform a perspective transform
# I've used the example grid image above to choose source points for the
# grid cell in front of the rover (each grid cell is 1 square meter in the sim)
# Define a function to perform a perspective transform
def perspect_transform(img, src, dst):
           
    M = cv2.getPerspectiveTransform(src, dst)
    warped = cv2.warpPerspective(img, M, (img.shape[1], img.shape[0]))# keep same size as input image
    
    return warped


# Define calibration box in source (actual) and destination (desired) coordinates
# These source and destination points are defined to warp the image
# to a grid where each 10x10 pixel square represents 1 square meter
# The destination box will be 2*dst_size on each side
dst_size = 5 
# Set a bottom offset to account for the fact that the bottom of the image 
# is not the position of the rover but a bit in front of it
# this is just a rough guess, feel free to change it!
bottom_offset = 6
source = np.float32([[14, 140], [301 ,140],[200, 96], [118, 96]])
destination = np.float32([[image.shape[1]/2 - dst_size, image.shape[0] - bottom_offset],
                  [image.shape[1]/2 + dst_size, image.shape[0] - bottom_offset],
                  [image.shape[1]/2 + dst_size, image.shape[0] - 2*dst_size - bottom_offset], 
                  [image.shape[1]/2 - dst_size, image.shape[0] - 2*dst_size - bottom_offset],
                  ])
warped = perspect_transform(grid_img, source, destination)
plt.imshow(warped)
#scipy.misc.imsave('../output/warped_example.jpg', warped)

# %% [markdown]
# ## Color Thresholding
# Define the color thresholding function from the lesson and apply it to the warped image
#
# **TODO:** Ultimately, you want your map to not just include navigable terrain but also obstacles and the positions of the rock samples you're searching for.  Modify this function or write a new function that returns the pixel locations of obstacles (areas below the threshold) and rock samples (yellow rocks in calibration images), such that you can map these areas into world coordinates as well.
# **Hints and Suggestion:**
# * For obstacles you can just invert your color selection that you used to detect ground pixels, i.e., if you've decided that everything above the threshold is navigable terrain, then everthing below the threshold must be an obstacle!
#
#
# * For rocks, think about imposing a lower and upper boundary in your color selection to be more specific about choosing colors.  You can investigate the colors of the rocks (the RGB pixel values) in an interactive matplotlib window to get a feel for the appropriate threshold range (keep in mind you may want different ranges for each of R, G and B!).  Feel free to get creative and even bring in functions from other libraries.  Here's an example of [color selection](http://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_colorspaces/py_colorspaces.html) using OpenCV.
#
# * **Beware However:** if you start manipulating images with OpenCV, keep in mind that it defaults to `BGR` instead of `RGB` color space when reading/writing images, so things can get confusing.

# %%
# Identify pixels above the threshold
# Threshold of RGB > 160 does a nice job of identifying ground pixels only
def color_thresh(img, rgb_thresh=(160, 160, 160)):
    # Create an array of zeros same xy size as img, but single channel
    color_select = np.zeros_like(img[:,:,0])
    # Require that each pixel be above all three threshold values in RGB
    # above_thresh will now contain a boolean array with "True"
    # where threshold was met
    above_thresh = (img[:,:,0] > rgb_thresh[0]) \
                & (img[:,:,1] > rgb_thresh[1]) \
                & (img[:,:,2] > rgb_thresh[2])
    # Index the array of zeros with the boolean array and set to 1
    color_select[above_thresh] = 1
    # Return the binary image
    return color_select

threshed = color_thresh(warped)
plt.imshow(threshed, cmap='gray')
#scipy.misc.imsave('../output/warped_threshed.jpg', threshed*255)

# %% [markdown]
# ## Coordinate Transformations
# Define the functions used to do coordinate transforms and apply them to an image.

# %%
def rover_coords(binary_img):
    # Identify nonzero pixels
    ypos, xpos = binary_img.nonzero()
    # Calculate pixel positions with reference to the rover position being at the 
    # center bottom of the image.  
    x_pixel = np.absolute(ypos - binary_img.shape[0]).astype(np.float)
    y_pixel = -(xpos - binary_img.shape[0]).astype(np.float)
    return x_pixel, y_pixel

# Define a function to convert to radial coords in rover space
def to_polar_coords(x_pixel, y_pixel):
    # Convert (x_pixel, y_pixel) to (distance, angle) 
    # in polar coordinates in rover space
    # Calculate distance to each pixel
    dist = np.sqrt(x_pixel**2 + y_pixel**2)
    # Calculate angle away from vertical for each pixel
    angles = np.arctan2(y_pixel, x_pixel)
    return dist, angles

# Define a function to apply a rotation to pixel positions
def rotate_pix(xpix, ypix, yaw):
    # TODO:
    # Convert yaw to radians
    # Apply a rotation
    yaw_rad = yaw * np.pi / 180
    xpix_rotated = xpix * np.cos(yaw_rad) - ypix * np.sin(yaw_rad)
    ypix_rotated = xpix * np.sin(yaw_rad) + ypix * np.cos(yaw_rad)
    # Return the result  
    return xpix_rotated, ypix_rotated

# Define a function to perform a translation
def translate_pix(xpix_rot, ypix_rot, xpos, ypos, scale): 
    # TODO:
    # Apply a scaling and a translation
    scale = 10
    # Perform translation and convert to integer since pixel values can't be float
    x_world = np.int_(xpos + (xpix_rot / scale))
    y_world = np.int_(ypos + (ypix_rot / scale))
    xpix_translated = xpos + x_world
    ypix_translated = ypos + y_world
    # Return the result  
    return xpix_translated, ypix_translated

# Define a function to apply rotation and translation (and clipping)
# Once you define the two functions above this function should work
def pix_to_world(xpix, ypix, xpos, ypos, yaw, world_size, scale):
    # Apply rotation
    xpix_rot, ypix_rot = rotate_pix(xpix, ypix, yaw)
    # Apply translation
    xpix_tran, ypix_tran = translate_pix(xpix_rot, ypix_rot, xpos, ypos, scale)
    # Perform rotation, translation and clipping all at once
    x_pix_world = np.clip(np.int_(xpix_tran), 0, world_size - 1)
    y_pix_world = np.clip(np.int_(ypix_tran), 0, world_size - 1)
    # Return the result
    return x_pix_world, y_pix_world

# Grab another random image
idx = np.random.randint(0, len(img_list)-1)
image = mpimg.imread(img_list[idx])
warped = perspect_transform(image, source, destination)
threshed = color_thresh(warped)

# Calculate pixel values in rover-centric coords and distance/angle to all pixels
xpix, ypix = rover_coords(threshed)
dist, angles = to_polar_coords(xpix, ypix)
mean_dir = np.mean(angles)

# Do some plotting
fig = plt.figure(figsize=(12,9))
plt.subplot(221)
plt.imshow(image)
plt.subplot(222)
plt.imshow(warped)
plt.subplot(223)
plt.imshow(threshed, cmap='gray')
plt.subplot(224)
plt.plot(xpix, ypix, '.')
plt.ylim(-160, 160)
plt.xlim(0, 160)
arrow_length = 100
x_arrow = arrow_length * np.cos(mean_dir)
y_arrow = arrow_length * np.sin(mean_dir)
plt.arrow(0, 0, x_arrow, y_arrow, color='red', zorder=2, head_width=10, width=2)

# %% [markdown]
# ## Read in saved data and ground truth map of the world
# The next cell is all setup to read your saved data into a `pandas` dataframe.  Here you'll also read in a "ground truth" map of the world, where white pixels (pixel value = 1) represent navigable terrain.
#
# After that, we'll define a class to store telemetry data and pathnames to images.  When you instantiate this class (`data = Databucket()`) you'll have a global variable called `data` that you can refer to for telemetry and map data within the `process_image()` function in the following cell.

# %%
# Import pandas and read in csv file as a dataframe
import pandas as pd
# Change the path below to your data directory
# If you are in a locale (e.g., Europe) that uses ',' as the decimal separator
# change the '.' to ','
#df = pd.read_csv('../test_dataset/robot_log.csv', delimiter=';', decimal='.')
csv_img_list = df["Path"].tolist() # Create list of image pathnames
# Read in ground truth map and create a 3-channel image with it
ground_truth = mpimg.imread('../calibration_images/map_bw.png')
ground_truth_3d = np.dstack((ground_truth*0, ground_truth*255, ground_truth*0)).astype(np.float)

# Creating a class to be the data container
# Will read in saved data from csv file and populate this object
# Worldmap is instantiated as 200 x 200 grids corresponding 
# to a 200m x 200m space (same size as the ground truth map: 200 x 200 pixels)
# This encompasses the full range of output position values in x and y from the sim
class Databucket():
    def __init__(self):
        self.images = csv_img_list  
        self.xpos = df["X_Position"].values
        self.ypos = df["Y_Position"].values
        self.yaw = df["Yaw"].values
        self.count = -1 # This will be a running index, setting to -1 is a hack
                        # because moviepy (below) seems to run one extra iteration
        self.worldmap = np.zeros((200, 200, 3)).astype(np.float)
        self.ground_truth = ground_truth_3d # Ground truth worldmap

# Instantiate a Databucket().. this will be a global variable/object
# that you can refer to in the process_image() function below
data = Databucket()

# %%
data.images
# Out:
# ['../test_dataset/IMG/robocam_2017_05_02_11_16_21_421.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_455.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_499.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_554.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_611.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_662.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_715.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_766.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_819.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_859.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_923.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_21_970.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_022.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_070.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_124.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_170.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_216.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_267.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_311.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_359.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_406.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_455.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_503.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_551.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_595.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_643.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_691.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_735.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_778.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_827.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_875.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_923.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_22_970.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_015.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_055.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_102.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_146.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_195.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_243.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_292.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_354.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_411.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_455.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_513.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_555.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_599.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_646.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_695.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_743.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_791.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_838.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_886.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_935.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_23_983.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_031.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_087.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_131.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_187.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_231.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_287.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_334.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_379.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_426.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_475.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_519.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_567.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_611.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_666.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_716.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_766.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_811.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_858.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_907.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_24_958.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_006.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_051.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_099.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_146.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_195.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_246.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_296.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_342.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_391.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_438.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_487.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_534.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_579.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_626.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_675.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_723.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_771.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_814.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_863.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_911.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_25_959.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_006.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_055.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_103.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_151.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_198.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_246.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_294.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_343.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_391.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_438.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_487.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_535.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_583.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_631.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_683.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_731.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_779.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_826.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_875.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_923.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_26_979.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_026.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_075.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_122.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_171.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_219.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_266.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_311.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_359.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_406.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_455.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_498.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_547.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_594.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_642.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_691.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_739.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_786.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_838.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_887.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_935.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_27_982.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_026.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_075.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_119.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_166.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_216.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_263.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_311.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_358.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_407.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_456.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_499.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_547.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_595.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_643.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_691.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_735.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_778.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_827.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_871.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_915.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_28_963.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_011.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_059.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_102.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_151.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_194.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_243.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_287.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_332.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_375.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_421.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_467.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_511.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_555.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_599.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_650.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_699.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_739.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_782.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_826.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_875.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_919.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_29_967.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_014.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_059.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_106.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_151.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_199.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_254.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_299.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_344.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_391.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_436.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_478.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_527.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_575.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_619.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_662.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_706.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_751.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_802.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_851.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_891.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_931.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_30_975.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_022.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_066.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_120.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_174.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_215.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_271.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_327.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_371.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_422.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_464.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_515.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_571.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_619.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_671.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_721.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_766.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_806.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_859.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_899.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_944.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_31_990.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_031.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_075.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_126.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_175.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_231.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_272.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_327.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_378.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_439.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_479.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_531.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_582.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_623.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_670.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_719.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_771.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_827.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_871.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_911.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_955.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_32_996.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_055.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_099.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_143.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_186.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_230.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_271.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_326.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_372.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_427.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_471.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_516.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_558.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_600.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_651.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_702.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_743.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_791.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_840.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_899.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_946.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_33_986.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_035.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_086.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_131.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_175.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_226.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_271.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_327.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_379.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_419.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_462.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_510.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_555.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_607.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_659.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_707.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_755.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_800.jpg',
#  '../test_dataset/IMG/robocam_2017_05_02_11_16_34_842.jpg']

# %% [markdown]
# ## Write a function to process stored images
#
# Modify the `process_image()` function below by adding in the perception step processes (functions defined above) to perform image analysis and mapping.  The following cell is all set up to use this `process_image()` function in conjunction with the `moviepy` video processing package to create a video from the images you saved taking data in the simulator.
#
# In short, you will be passing individual images into `process_image()` and building up an image called `output_image` that will be stored as one frame of video.  You can make a mosaic of the various steps of your analysis process and add text as you like (example provided below).
#
#
#
# To start with, you can simply run the next three cells to see what happens, but then go ahead and modify them such that the output video demonstrates your mapping process.  Feel free to get creative!

# %%
# Define a function to pass stored images to
# reading rover position and yaw angle from csv file
# This function will be used by moviepy to create an output video
def process_image(img):
    # Example of how to use the Databucket() object defined above
    # to print the current x, y and yaw values 
    # print(data.xpos[data.count], data.ypos[data.count], data.yaw[data.count])

    # TODO: 
    # 1) Define source and destination points for perspective transform
    bottom_offset = 6
    source = np.float32([[14, 140], [301 ,140],[200, 96], [118, 96]])
    destination = np.float32([[image.shape[1]/2 - dst_size, image.shape[0] - bottom_offset],
                  [image.shape[1]/2 + dst_size, image.shape[0] - bottom_offset],
                  [image.shape[1]/2 + dst_size, image.shape[0] - 2*dst_size - bottom_offset], 
                  [image.shape[1]/2 - dst_size, image.shape[0] - 2*dst_size - bottom_offset],
                  ])
    # 2) Apply perspective transform
    warped = perspect_transform(image, source, destination)
    # 3) Apply color threshold to identify navigable terrain/obstacles/rock samples
    threshed = color_thresh(warped)
    # 4) Convert thresholded image pixel values to rover-centric coords
    xpix, ypix = rover_coords(threshed)
    scale = 10
    
    rover_yaw = data.yaw[data.count]


    rover_xpos = data.xpos[data.count]
    rover_ypos = data.ypos[data.count]
    x_world, y_world = pix_to_world(xpix, ypix, rover_xpos, 
                                rover_ypos, rover_yaw, 
                                data.worldmap.shape[0], scale)
    
    # 5) Convert rover-centric pixel values to world coords
    dist, angles = to_polar_coords(xpix, ypix)
    # 6) Update worldmap (to be displayed on right side of screen)
        # Example: data.worldmap[obstacle_y_world, obstacle_x_world, 0] += 1
        #          data.worldmap[rock_y_world, rock_x_world, 1] += 1
        #          data.worldmap[navigable_y_world, navigable_x_world, 2] += 1
    data.worldmap[y_world, x_world, 2] += 1
    data.worldmap[y_world, x_world, 1] += 1
    data.worldmap[y_world, x_world, 0] += 1
    # 7) Make a mosaic image, below is some example code
        # First create a blank image (can be whatever shape you like)
    output_image = np.zeros((img.shape[0] + data.worldmap.shape[0], img.shape[1]*2, 3))
        # Next you can populate regions of the image with various output
        # Here I'm putting the original image in the upper left hand corner
    output_image[0:img.shape[0], 0:img.shape[1]] = img

        # Let's create more images to add to the mosaic, first a warped image
    warped = perspect_transform(img, source, destination)
        # Add the warped image in the upper right hand corner
    output_image[0:img.shape[0], img.shape[1]:] = warped

        # Overlay worldmap with ground truth map
    map_add = cv2.addWeighted(data.worldmap, 1, data.ground_truth, 0.5, 0)
        # Flip map overlay so y-axis points upward and add to output_image 
    output_image[img.shape[0]:, 0:data.worldmap.shape[1]] = np.flipud(map_add)


        # Then putting some text over the image
    cv2.putText(output_image,"Populate this image with your analyses to make a video!", (20, 20), 
                cv2.FONT_HERSHEY_COMPLEX, 0.4, (255, 255, 255), 1)
    data.count += 1 # Keep track of the index in the Databucket()
    
    return output_image

# %% [markdown]
# ## Make a video from processed image data
# Use the [moviepy](https://zulko.github.io/moviepy/) library to process images and create a video.

# %%
import imageio
imageio.plugins.ffmpeg.download()

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from moviepy.editor import ImageSequenceClip


# Define pathname to save the output video
output = '../output/test_mapping.mp4'
data = img_list # Re-initialize data in case you're running this cell multiple times
clip = ImageSequenceClip(data, fps=60) # Note: output video will be sped up because 
                                          # recording rate in simulator is fps=25
new_clip = clip.fl_image(process_image) #NOTE: this function expects color images!!
# %time new_clip.write_videofile(output, audio=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-439c18636a4a> in <module>()
#       9 clip = ImageSequenceClip(data, fps=60) # Note: output video will be sped up because
#      10                                           # recording rate in simulator is fps=25
# ---> 11 new_clip = clip.fl_image(process_image) #NOTE: this function expects color images!!
#      12 get_ipython().magic('time new_clip.write_videofile(output, audio=False)')
#
# /Users/admin/anaconda2/envs/RoboND/lib/python3.5/site-packages/moviepy/video/VideoClip.py in fl_image(self, image_func, apply_to)
#     531         `get_frame(t)` by another frame,  `image_func(get_frame(t))`
#     532         """
# --> 533         return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#     534
#     535     # --------------------------------------------------------------
#
# /Users/admin/anaconda2/envs/RoboND/lib/python3.5/site-packages/moviepy/Clip.py in fl(self, fun, apply_to, keep_duration)
#     134
#     135         #mf = copy(self.make_frame)
# --> 136         newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     137
#     138         if not keep_duration:
#
# <decorator-gen-179> in set_make_frame(self, mf)
#
# /Users/admin/anaconda2/envs/RoboND/lib/python3.5/site-packages/moviepy/decorators.py in outplace(f, clip, *a, **k)
#      12     """ Applies f(clip.copy(), *a, **k) and returns clip.copy()"""
#      13     newclip = clip.copy()
# ---> 14     f(newclip, *a, **k)
#      15     return newclip
#      16
#
# /Users/admin/anaconda2/envs/RoboND/lib/python3.5/site-packages/moviepy/video/VideoClip.py in set_make_frame(self, mf)
#     692         """
#     693         self.make_frame = mf
# --> 694         self.size = self.get_frame(0).shape[:2][::-1]
#     695
#     696
#
# <decorator-gen-136> in get_frame(self, t)
#
# /Users/admin/anaconda2/envs/RoboND/lib/python3.5/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_261.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_296.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_333.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_372.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_413.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_452.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_490.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_527.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_564.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_614.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_666.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_720.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_770.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_808.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_851.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_888.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_925.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_07_963.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_000.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_038.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_077.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_121.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_163.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_205.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_245.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_298.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_340.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_381.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_421.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_461.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_501.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_543.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_580.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_620.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_658.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_705.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_763.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_804.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_845.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_882.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_921.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_959.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_08_994.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_033.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_071.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_108.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_145.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_182.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_222.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_258.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_292.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_338.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_376.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_422.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_466.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_507.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_543.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_591.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_633.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_675.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_715.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_761.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_850.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_894.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_930.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_09_976.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_021.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_059.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_096.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_133.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_172.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_213.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_252.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_295.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_334.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_374.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_412.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_450.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_489.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_528.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_569.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_608.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_647.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_694.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_731.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_769.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_811.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_850.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_895.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_942.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_10_979.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_027.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_068.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_113.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_161.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_201.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_241.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_278.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_320.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_364.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_408.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_449.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_491.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_532.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_570.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_610.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_652.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_687.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_725.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_765.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_803.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_847.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_897.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_935.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_11_973.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_030.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_071.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_109.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_155.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_204.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_243.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_281.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_324.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_364.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_401.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_441.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_486.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_529.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_571.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_615.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_654.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_694.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_736.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_780.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_822.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_863.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_904.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_942.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_12_988.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_029.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_067.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_126.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_162.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_207.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_252.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_304.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_344.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_381.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_423.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_462.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_498.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_541.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_588.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_631.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_673.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_713.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_752.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_792.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_833.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_873.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_916.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_13_959.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_005.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_043.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_084.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_124.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_162.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_215.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_253.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_293.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_335.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_382.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_428.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_465.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_504.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_540.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_579.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_621.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_661.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_699.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_738.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_776.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_817.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_855.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_893.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_935.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_14_979.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_022.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_065.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_106.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_146.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_190.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_227.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_313.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_357.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_394.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_430.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_471.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_514.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_552.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_592.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_635.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_681.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_732.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_769.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_812.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_849.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_890.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_929.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_15_969.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_013.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_051.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_091.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_135.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_174.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_213.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_251.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_294.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_330.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_385.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_431.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_468.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_513.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_551.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_594.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_631.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_669.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_706.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_743.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_783.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_833.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_877.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_927.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_16_968.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_008.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_046.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_085.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_125.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_165.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_204.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_241.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_281.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_321.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_364.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_401.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_438.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_499.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_539.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_576.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_616.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_655.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_696.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_731.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_767.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_808.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_845.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_881.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_919.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_958.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_17_997.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_042.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_087.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_130.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_168.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_209.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_249.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_290.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_327.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_366.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_409.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_448.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_487.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_529.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_587.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_631.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_671.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_715.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_754.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_792.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_834.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_872.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_915.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_955.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_18_993.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_033.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_074.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_118.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_159.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_202.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_241.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_281.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_333.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_378.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_427.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_466.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_509.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_554.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_594.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_635.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_688.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_728.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_770.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_810.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_850.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_888.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_926.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_19_967.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_20_006.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_20_043.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_20_086.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_20_138.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_20_192.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_20_231.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_20_276.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_20_318.jpg',
#  '../test_dataset/IMG/2017_05_31_12_58_20_359.jpg',
#  ...]

# %% [markdown]
# ### This next cell should function as an inline video player
# If this fails to render the video, try running the following cell (alternative video rendering method).  You can also simply have a look at the saved mp4 in your `/output` folder

# %%
from IPython.display import HTML
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(output))
# Out:
# <video width="960" height="540" controls>
#   <source src="../output/test_mapping.mp4">
# </video>

# %% [markdown]
# ### Below is an alternative way to create a video in case the above cell did not work.

# %%
import io
import base64
video = io.open(output, 'r+b').read()
encoded_video = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded_video.decode('ascii')))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
